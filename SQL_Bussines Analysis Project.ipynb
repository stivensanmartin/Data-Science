# %% [markdown]
# # SQL Project, Answering Business Questions

# %% [markdown]
# Importing libraries needed

# %%
import matplotlib.pyplot as plt
import sqlite3
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# First, we create some functions that will optimize the query execution

# %%
def run_query(c):
    with sqlite3.connect('chinook.db') as conn:
        return pd.read_sql(c, conn)

# %%
def run_command(c):
    with sqlite3.connect('chinook.db') as conn:
        conn.isolation_level = None
        conn.execute(c)

# %%
def show_tables():
    query = '''
    SELECT 
        name, 
        type 
    FROM sqlite_master 
    WHERE type IN ("table", "view");
            '''
    return run_query(query)

# %%
show_tables()
# Out:
#                name   type
# 0             album  table
# 1            artist  table
# 2          customer  table
# 3          employee  table
# 4             genre  table
# 5           invoice  table
# 6      invoice_line  table
# 7        media_type  table
# 8          playlist  table
# 9    playlist_track  table
# 10            track  table
# 11  countries_sales   view

# %% [markdown]
# ## Genres that sold most tracks

# %%
query_1 = '''
WITH track_info AS
(
    SELECT 
        t.genre_id,
        il.track_id, 
        SUM(il.quantity) quantity
    FROM track t
    INNER JOIN invoice_line il
    ON il.track_id = t.track_id
    INNER JOIN invoice i
    ON i.invoice_id = il.invoice_id
    INNER JOIN customer c
    ON c.customer_id = i.customer_id
    WHERE c.country = 'USA'
    GROUP BY t.genre_id, il.track_id
    ORDER BY quantity DESC
)
SELECT 
    g.name Genre, 
    SUM(ti.quantity) Tracks_sold, 
    ROUND(SUM(CAST(ti.quantity AS FLOAT))/CAST((
    SELECT SUM(quantity) FROM track_info
    ) AS FLOAT)*100, 1) Percentage
    FROM track_info ti
    INNER JOIN genre g
    ON g.genre_id = ti.genre_id
    GROUP BY g.name
    ORDER BY 2 DESC
'''
df_genres = run_query(query_1)

# %%
df_genres.head()
# Out:
#                 Genre  Tracks_sold  Percentage
# 0                Rock          561        53.4
# 1  Alternative & Punk          130        12.4
# 2               Metal          124        11.8
# 3            R&B/Soul           53         5.0
# 4               Blues           36         3.4

# %%
chart = sns.barplot(x='Genre', y='Tracks_sold', data=df_genres)
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
# Out:
# /dataquest/system/env/python3/lib/python3.4/site-packages/seaborn/categorical.py:1428: FutureWarning:
#
# remove_na is deprecated and is a private function. Do not use.
# [<matplotlib.text.Text at 0x7f3c25a13d30>,
#  <matplotlib.text.Text at 0x7f3c25a17208>,
#  <matplotlib.text.Text at 0x7f3c259b1080>,
#  <matplotlib.text.Text at 0x7f3c259b1b70>,
#  <matplotlib.text.Text at 0x7f3c259b56a0>,
#  <matplotlib.text.Text at 0x7f3c259381d0>,
#  <matplotlib.text.Text at 0x7f3c25938cc0>,
#  <matplotlib.text.Text at 0x7f3c2593e7f0>,
#  <matplotlib.text.Text at 0x7f3c25940320>,
#  <matplotlib.text.Text at 0x7f3c25940e10>,
#  <matplotlib.text.Text at 0x7f3c25945940>,
#  <matplotlib.text.Text at 0x7f3c25948470>,
#  <matplotlib.text.Text at 0x7f3c25948f60>,
#  <matplotlib.text.Text at 0x7f3c2594aa90>,
#  <matplotlib.text.Text at 0x7f3c259515c0>,
#  <matplotlib.text.Text at 0x7f3c259530f0>,
#  <matplotlib.text.Text at 0x7f3c25953be0>]

# %% [markdown]
# ## Analysis
# As we see, the top 3 most sold genres are pretty similar, but the first have most than 50% of the market

# %% [markdown]
# ## Sales per Agent

# %%
query_2 = '''
SELECT 
    e.hire_date,
    e.first_name || " " || e.last_name Employee,
    SUM(i.total) Sales
FROM customer c
INNER JOIN invoice i
ON i.customer_id = c.customer_id
INNER JOIN employee e
ON e.employee_id = c.support_rep_id
GROUP BY c.support_rep_id
ORDER BY sales DESC
'''
df_employee = run_query(query_2)

# %%
df_employee
# Out:
#              hire_date       Employee    Sales
# 0  2017-04-01 00:00:00   Jane Peacock  1731.51
# 1  2017-05-03 00:00:00  Margaret Park  1584.00
# 2  2017-10-17 00:00:00  Steve Johnson  1393.92

# %%
chart = sns.barplot(x='Employee', y='Sales', data=df_employee)
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
# Out:
# /dataquest/system/env/python3/lib/python3.4/site-packages/seaborn/categorical.py:1428: FutureWarning:
#
# remove_na is deprecated and is a private function. Do not use.
# [<matplotlib.text.Text at 0x7f3c258b60f0>,
#  <matplotlib.text.Text at 0x7f3c258ce5f8>,
#  <matplotlib.text.Text at 0x7f3c25887400>]

# %% [markdown]
# ## Analysis
# Taking in acount the hire date we can explain why the order Jane is the first, Margaret the second and Steve the third

# %% [markdown]
# ## Customers and Sales per Country

# %%
#query_3 = '''
#CREATE VIEW countries_sales AS 
#    SELECT 
#        CASE 
#            WHEN COUNT(DISTINCT c.customer_id) == 1 THEN 'Other'
#            ELSE c.country
#        END Countries,
#        COUNT(DISTINCT c.customer_id) Number_Customers,
#        SUM(i.total) Sales,
#        AVG(i.total) Avg_Sales
#    FROM customer c
#    INNER JOIN invoice i
#    ON c.customer_id = i.customer_id
#    GROUP BY c.country
#    ORDER BY 3 DESC;
#'''
#run_command(query_3)

# %%
query_4 ='''
SELECT 
    Countries, 
    SUM(Number_Customers) N_Customer, 
    SUM(Sales) Sales,
    AVG(Avg_Sales) Avg_Sales
FROM countries_sales
GROUP BY countries
ORDER BY 2 DESC
'''
df_countries = run_query(query_4)

# %%
df_countries
# Out:
#         Countries  N_Customer    Sales  Avg_Sales
# 0           Other          15  1094.94   7.445071
# 1             USA          13  1040.49   7.942672
# 2          Canada           8   535.59   7.047237
# 3          Brazil           5   427.68   7.011148
# 4          France           5   389.07   7.781400
# 5         Germany           4   334.62   8.161463
# 6  United Kingdom           3   245.52   8.768571
# 7  Czech Republic           2   273.24   9.108000
# 8           India           2   183.15   8.721429
# 9        Portugal           2   185.13   6.383793

# %%
chart = sns.barplot(x='Countries', y='N_Customer', data=df_countries[df_countries['Countries']!='Other'])
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
# Out:
# /dataquest/system/env/python3/lib/python3.4/site-packages/seaborn/categorical.py:1428: FutureWarning:
#
# remove_na is deprecated and is a private function. Do not use.
# [<matplotlib.text.Text at 0x7f3c258b69b0>,
#  <matplotlib.text.Text at 0x7f3c258374a8>,
#  <matplotlib.text.Text at 0x7f3c25828780>,
#  <matplotlib.text.Text at 0x7f3c2582c2b0>,
#  <matplotlib.text.Text at 0x7f3c2582cda0>,
#  <matplotlib.text.Text at 0x7f3c2582f8d0>,
#  <matplotlib.text.Text at 0x7f3c25833400>,
#  <matplotlib.text.Text at 0x7f3c25833ef0>,
#  <matplotlib.text.Text at 0x7f3c257b6a20>]

# %%
chart = sns.barplot(x='Countries', y='Sales', data=df_countries[df_countries['Countries']!='Other'])
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
# Out:
# /dataquest/system/env/python3/lib/python3.4/site-packages/seaborn/categorical.py:1428: FutureWarning:
#
# remove_na is deprecated and is a private function. Do not use.
# [<matplotlib.text.Text at 0x7f3c259480f0>,
#  <matplotlib.text.Text at 0x7f3c257e7c18>,
#  <matplotlib.text.Text at 0x7f3c257490f0>,
#  <matplotlib.text.Text at 0x7f3c25749be0>,
#  <matplotlib.text.Text at 0x7f3c2574c710>,
#  <matplotlib.text.Text at 0x7f3c2574e240>,
#  <matplotlib.text.Text at 0x7f3c2574ed30>,
#  <matplotlib.text.Text at 0x7f3c25754860>,
#  <matplotlib.text.Text at 0x7f3c25757390>]

# %%
chart = sns.barplot(x='Countries', y='Avg_Sales', data=df_countries[df_countries['Countries']!='Other'])
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
# Out:
# /dataquest/system/env/python3/lib/python3.4/site-packages/seaborn/categorical.py:1428: FutureWarning:
#
# remove_na is deprecated and is a private function. Do not use.
# [<matplotlib.text.Text at 0x7f3c257004e0>,
#  <matplotlib.text.Text at 0x7f3c2570d710>,
#  <matplotlib.text.Text at 0x7f3c256e9c88>,
#  <matplotlib.text.Text at 0x7f3c256ee7b8>,
#  <matplotlib.text.Text at 0x7f3c256f32e8>,
#  <matplotlib.text.Text at 0x7f3c256f3dd8>,
#  <matplotlib.text.Text at 0x7f3c256f5908>,
#  <matplotlib.text.Text at 0x7f3c25679438>,
#  <matplotlib.text.Text at 0x7f3c25679f28>]

# %% [markdown]
# ## Analysis
# The USA is the country with most customers and sales, but Czech Republic is the country in wich in average the sales per customer is higer

# %%
query_6 ='''
SELECT
    a.album_id,
    a.title,
    t.track_id,
    t.name
FROM album a
INNER JOIN track t
ON a.album_id = t.album_id
'''
run_query(query_6)
# Out:
#       album_id                                              title  track_id  \
# 0            1              For Those About To Rock We Salute You         1
# 1            2                                  Balls to the Wall         2
# 2            3                                  Restless and Wild         3
# 3            3                                  Restless and Wild         4
# 4            3                                  Restless and Wild         5
# 5            1              For Those About To Rock We Salute You         6
# 6            1              For Those About To Rock We Salute You         7
# 7            1              For Those About To Rock We Salute You         8
# 8            1              For Those About To Rock We Salute You         9
# 9            1              For Those About To Rock We Salute You        10
# 10           1              For Those About To Rock We Salute You        11
# 11           1              For Those About To Rock We Salute You        12
# 12           1              For Those About To Rock We Salute You        13
# 13           1              For Those About To Rock We Salute You        14
# 14           4                                  Let There Be Rock        15
# 15           4                                  Let There Be Rock        16
# 16           4                                  Let There Be Rock        17
# 17           4                                  Let There Be Rock        18
# 18           4                                  Let There Be Rock        19
# 19           4                                  Let There Be Rock        20
# 20           4                                  Let There Be Rock        21
# 21           4                                  Let There Be Rock        22
# 22           5                                           Big Ones        23
# 23           5                                           Big Ones        24
# 24           5                                           Big Ones        25
# 25           5                                           Big Ones        26
# 26           5                                           Big Ones        27
# 27           5                                           Big Ones        28
# 28           5                                           Big Ones        29
# 29           5                                           Big Ones        30
# ...        ...                                                ...       ...
# 3473       322                                              Frank      3474
# 3474       322                                              Frank      3475
# 3475       322                                              Frank      3476
# 3476       322                                              Frank      3477
# 3477       323              Carried to Dust (Bonus Track Version)      3478
# 3478       324          Beethoven: Symphony No. 6 'Pastoral' Etc.      3479
# 3479       325                   Bartok: Violin & Viola Concertos      3480
# 3480       326             Mendelssohn: A Midsummer Night's Dream      3481
# 3481       327                 Bach: Orchestral Suites Nos. 1 - 4      3482
# 3482       328      Charpentier: Divertissements, Airs & Concerts      3483
# 3483       329                             South American Getaway      3484
# 3484       330                            Górecki: Symphony No. 3      3485
# 3485       331                           Purcell: The Fairy Queen      3486
# 3486       332                      The Ultimate Relexation Album      3487
# 3487       333                  Purcell: Music for the Queen Mary      3488
# 3488       334                       Weill: The Seven Deadly Sins      3489
# 3489       335  J.S. Bach: Chaconne, Suite in E Minor, Partita...      3490
# 3490       336  Prokofiev: Symphony No.5 & Stravinksy: Le Sacr...      3491
# 3491       314                                English Renaissance      3492
# 3492       337                   Szymanowski: Piano Works, Vol. 1      3493
# 3493       338                        Nielsen: The Six Symphonies      3494
# 3494       339  Great Recordings of the Century: Paganini's 24...      3495
# 3495       340        Liszt - 12 Études D'Execution Transcendante      3496
# 3496       341  Great Recordings of the Century - Shubert: Sch...      3497
# 3497       342  Locatelli: Concertos for Violin, Strings and C...      3498
# 3498       343                             Respighi:Pines of Rome      3499
# 3499       344  Schubert: The Late String Quartets & String Qu...      3500
# 3500       345                                Monteverdi: L'Orfeo      3501
# 3501       346                              Mozart: Chamber Music      3502
# 3502       347  Koyaanisqatsi (Soundtrack from the Motion Pict...      3503
#
#                                                    name
# 0               For Those About To Rock (We Salute You)
# 1                                     Balls to the Wall
# 2                                       Fast As a Shark
# 3                                     Restless and Wild
# 4                                  Princess of the Dawn
# 5                                 Put The Finger On You
# 6                                       Let's Get It Up
# 7                                      Inject The Venom
# 8                                            Snowballed
# 9                                            Evil Walks
# 10                                               C.O.D.
# 11                                   Breaking The Rules
# 12                             Night Of The Long Knives
# 13                                           Spellbound
# 14                                              Go Down
# 15                                          Dog Eat Dog
# 16                                    Let There Be Rock
# 17                                       Bad Boy Boogie
# 18                                        Problem Child
# 19                                             Overdose
# 20                         Hell Ain't A Bad Place To Be
# 21                                    Whole Lotta Rosie
# 22                                        Walk On Water
# 23                                  Love In An Elevator
# 24                                             Rag Doll
# 25                                        What It Takes
# 26                             Dude (Looks Like A Lady)
# 27                                    Janie's Got A Gun
# 28                                               Cryin'
# 29                                              Amazing
# ...                                                 ...
# 3473                                       October Song
# 3474                               What Is It About Men
# 3475                                      Help Yourself
# 3476                                Amy Amy Amy (Outro)
# 3477                                           Slowness
# 3478                        Prometheus Overture, Op. 43
# 3479                 Sonata for Solo Violin: IV: Presto
# 3480  A Midsummer Night's Dream, Op.61 Incidental Mu...
# 3481    Suite No. 3 in D, BWV 1068: III. Gavotte I & II
# 3482  Concert pour 4 Parties de V**les, H. 545: I. P...
# 3483                                       Adios nonino
# 3484  Symphony No. 3 Op. 36 for Orchestra and Sopran...
# 3485                                   Act IV, Symphony
# 3486  3 Gymnopédies: No.1 - Lent Et Grave, No.3 - Le...
# 3487  Music for the Funeral of Queen Mary: VI. "Thou...
# 3488                Symphony No. 2: III. Allegro vivace
# 3489          Partita in E Major, BWV 1006A: I. Prelude
# 3490         Le Sacre Du Printemps: I.iv. Spring Rounds
# 3491                                      Sing Joyfully
# 3492                           Metopes, Op. 29: Calypso
# 3493  Symphony No. 2, Op. 16 -  "The Four Temperamen...
# 3494  24 Caprices, Op. 1, No. 24, for Solo Violin, i...
# 3495    Étude 1, In C Major - Preludio (Presto) - Liszt
# 3496                                    Erlkonig, D.328
# 3497  Concerto for Violin, Strings and Continuo in G...
# 3498  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...
# 3499  String Quartet No. 12 in C Minor, D. 703 "Quar...
# 3500               L'orfeo, Act 3, Sinfonia (Orchestra)
# 3501  Quintet for Horn, Violin, 2 Violas, and Cello ...
# 3502                                      Koyaanisqatsi
#
# [3503 rows x 4 columns]
